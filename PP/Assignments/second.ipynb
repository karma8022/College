# %%
from matplotlib import pyplot as plt
plt.plot([1,2,3],[4,5,6])
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.xlabel("X-axis")
# Out:
# Text(0.5, 0, 'X-axis')

# %%
plt.bar([1,3,5],[6,9,10],label="Bar1")
plt.legend()
plt.show()

# %%
import numpy as np
x = np.random.normal(170,10,250)
plt.hist(x)
plt.show()
